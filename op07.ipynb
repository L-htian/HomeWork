# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv("over_point_to_case_type.csv",index_col=[0])
data1
# Out:
#        case_id          case_type  final_score  user_id    upload_time  score  \
# 0         2908             string         40.0     3544  1582023290656   40.0
# 1         2908             string         40.0     3544  1582557830339    0.0
# 2         2908             string         40.0     3544  1582557836610    0.0
# 3         2908             string         40.0     3544  1582558130645    0.0
# 4         2908             string         40.0     3544  1582558139684    0.0
# ...        ...                ...          ...      ...            ...    ...
# 87729     2533  sorting_algorithm        100.0    47879  1581990689121  100.0
# 87730     2542  sorting_algorithm        100.0    47879  1582467717077  100.0
# 87731     2528  sorting_algorithm        100.0    47879  1581991378741  100.0
# 87732     2528  sorting_algorithm        100.0    47879  1582467418780  100.0
# 87733     2542  sorting_algorithm          0.0    60822  1581949768102    0.0
#
#        over_point
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 87729   83.333333
# 87730   83.333333
# 87731   83.333333
# 87732   83.333333
# 87733    0.000000
#
# [87734 rows x 7 columns]

# %%
data2 = pd.read_csv("over_point_to_user.csv",index_col=[0])
data2
# Out:
#        case_id          case_type  final_score  user_id    upload_time  score  \
# 0         2908             string         40.0     3544  1582023290656   40.0
# 1         2908             string         40.0     3544  1582557830339    0.0
# 2         2908             string         40.0     3544  1582557836610    0.0
# 3         2908             string         40.0     3544  1582558130645    0.0
# 4         2908             string         40.0     3544  1582558139684    0.0
# ...        ...                ...          ...      ...            ...    ...
# 87729     2533  sorting_algorithm        100.0    47879  1581990689121  100.0
# 87730     2542  sorting_algorithm        100.0    47879  1582467717077  100.0
# 87731     2528  sorting_algorithm        100.0    47879  1581991378741  100.0
# 87732     2528  sorting_algorithm        100.0    47879  1582467418780  100.0
# 87733     2542  sorting_algorithm          0.0    60822  1581949768102    0.0
#
#        over_point
# 0      160.967187
# 1      160.967187
# 2      160.967187
# 3      160.967187
# 4      160.967187
# ...           ...
# 87729   83.333333
# 87730   83.333333
# 87731   83.333333
# 87732   83.333333
# 87733    0.000000
#
# [87734 rows x 7 columns]

# %%
data3 = data1
data3["upload_time"] = pd.to_datetime(data3["upload_time"],unit="ms")
data3
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 1         2908             string         40.0     3544
# 2         2908             string         40.0     3544
# 3         2908             string         40.0     3544
# 4         2908             string         40.0     3544
# ...        ...                ...          ...      ...
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87732     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                   upload_time  score  over_point
# 0     2020-02-18 10:54:50.656   40.0    0.000000
# 1     2020-02-24 15:23:50.339    0.0    0.000000
# 2     2020-02-24 15:23:56.610    0.0    0.000000
# 3     2020-02-24 15:28:50.645    0.0    0.000000
# 4     2020-02-24 15:28:59.684    0.0    0.000000
# ...                       ...    ...         ...
# 87729 2020-02-18 01:51:29.121  100.0   83.333333
# 87730 2020-02-23 14:21:57.077  100.0   83.333333
# 87731 2020-02-18 02:02:58.741  100.0   83.333333
# 87732 2020-02-23 14:16:58.780  100.0   83.333333
# 87733 2020-02-17 14:29:28.102    0.0    0.000000
#
# [87734 rows x 7 columns]

# %%
type(int(data3.iloc[0].loc["upload_time"].strftime("%m")))
# Out:
# int

# %%
days = []
for i in range(87734):
    month = data3.iloc[i].loc["upload_time"].strftime("%m")
    month = int(month)
    day = data3.iloc[i].loc["upload_time"].strftime("%d")
    day = int(day)
    day = day - 16 + (month - 2) * 29
    days.append(day)
data3["days"] = days

# %%
data3
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 1         2908             string         40.0     3544
# 2         2908             string         40.0     3544
# 3         2908             string         40.0     3544
# 4         2908             string         40.0     3544
# ...        ...                ...          ...      ...
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87732     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                   upload_time  score  over_point  days
# 0     2020-02-18 10:54:50.656   40.0    0.000000     2
# 1     2020-02-24 15:23:50.339    0.0    0.000000     8
# 2     2020-02-24 15:23:56.610    0.0    0.000000     8
# 3     2020-02-24 15:28:50.645    0.0    0.000000     8
# 4     2020-02-24 15:28:59.684    0.0    0.000000     8
# ...                       ...    ...         ...   ...
# 87729 2020-02-18 01:51:29.121  100.0   83.333333     2
# 87730 2020-02-23 14:21:57.077  100.0   83.333333     7
# 87731 2020-02-18 02:02:58.741  100.0   83.333333     2
# 87732 2020-02-23 14:16:58.780  100.0   83.333333     7
# 87733 2020-02-17 14:29:28.102    0.0    0.000000     1
#
# [87734 rows x 8 columns]

# %%
day_count = data3["days"].value_counts().drop(labels=[-1,-2])
day_count
# Out:
# 44    6625
# 43    4125
# 3     3134
# 2     3063
# 6     2925
# 7     2882
# 16    2829
# 14    2464
# 11    2444
# 13    2440
# 9     2433
# 5     2378
# 42    2302
# 8     2169
# 4     2162
# 30    2143
# 15    2108
# 17    2100
# 12    2085
# 10    1993
# 31    1862
# 32    1836
# 29    1807
# 36    1761
# 41    1719
# 35    1699
# 38    1643
# 40    1550
# 28    1549
# 34    1511
# 33    1440
# 1     1431
# 27    1431
# 37    1404
# 39    1368
# 18    1297
# 26    1272
# 21    1070
# 22    1001
# 20     940
# 24     930
# 25     906
# 23     734
# 19     611
# Name: days, dtype: int64

# %%
data4 = data1
data4["upload_time"].min()
# Out:
# Timestamp('2020-02-14 04:40:12.448000')

# %%
day_count.sort_index(inplace=True)
day_count
# Out:
# 1     1431
# 2     3063
# 3     3134
# 4     2162
# 5     2378
# 6     2925
# 7     2882
# 8     2169
# 9     2433
# 10    1993
# 11    2444
# 12    2085
# 13    2440
# 14    2464
# 15    2108
# 16    2829
# 17    2100
# 18    1297
# 19     611
# 20     940
# 21    1070
# 22    1001
# 23     734
# 24     930
# 25     906
# 26    1272
# 27    1431
# 28    1549
# 29    1807
# 30    2143
# 31    1862
# 32    1836
# 33    1440
# 34    1511
# 35    1699
# 36    1761
# 37    1404
# 38    1643
# 39    1368
# 40    1550
# 41    1719
# 42    2302
# 43    4125
# 44    6625
# Name: days, dtype: int64

# %%
plt.plot(day_count)

# %%
data4 = data3.drop_duplicates(subset=["case_id","user_id"])
data4
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 24        2172       linear_table        100.0     3544
# 32        2176              array         50.0     3544
# 36        2307              array         25.0     3544
# 37        2804              array          0.0     3544
# ...        ...                ...          ...      ...
# 87728     2534  sorting_algorithm        100.0    47879
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                   upload_time  score  over_point  days
# 0     2020-02-18 10:54:50.656   40.0    0.000000     2
# 24    2020-03-03 05:31:40.962  100.0  100.000000    16
# 32    2020-02-17 14:09:14.050    0.0   41.967188     1
# 36    2020-03-14 14:45:29.500   25.0   41.967188    27
# 37    2020-02-19 09:09:16.125    0.0   41.967188     3
# ...                       ...    ...         ...   ...
# 87728 2020-02-18 03:27:02.535  100.0   83.333333     2
# 87729 2020-02-18 01:51:29.121  100.0   83.333333     2
# 87730 2020-02-23 14:21:57.077  100.0   83.333333     7
# 87731 2020-02-18 02:02:58.741  100.0   83.333333     2
# 87733 2020-02-17 14:29:28.102    0.0    0.000000     1
#
# [42776 rows x 8 columns]

# %%
day_count2 = data4["days"].value_counts().drop(labels=[-1,-2])
day_count2
# Out:
# 44    3590
# 43    1762
# 2     1545
# 3     1523
# 7     1413
# 6     1335
# 16    1278
# 5     1220
# 42    1209
# 14    1173
# 13    1165
# 4     1152
# 11    1135
# 17    1068
# 9     1054
# 12    1051
# 30     997
# 15     985
# 10     967
# 8      949
# 29     933
# 28     885
# 35     849
# 31     843
# 32     829
# 36     811
# 1      784
# 27     764
# 41     753
# 39     733
# 34     713
# 37     710
# 38     684
# 18     680
# 26     655
# 33     652
# 40     641
# 21     579
# 24     481
# 25     465
# 20     430
# 22     426
# 19     406
# 23     362
# Name: days, dtype: int64

# %%
day_count2.sort_index(inplace=True)
day_count2
# Out:
# 1      784
# 2     1545
# 3     1523
# 4     1152
# 5     1220
# 6     1335
# 7     1413
# 8      949
# 9     1054
# 10     967
# 11    1135
# 12    1051
# 13    1165
# 14    1173
# 15     985
# 16    1278
# 17    1068
# 18     680
# 19     406
# 20     430
# 21     579
# 22     426
# 23     362
# 24     481
# 25     465
# 26     655
# 27     764
# 28     885
# 29     933
# 30     997
# 31     843
# 32     829
# 33     652
# 34     713
# 35     849
# 36     811
# 37     710
# 38     684
# 39     733
# 40     641
# 41     753
# 42    1209
# 43    1762
# 44    3590
# Name: days, dtype: int64

# %%
plt.plot(day_count2)

# %%
hours = []
for i in range(87734):
    hour = data3.iloc[i].loc["upload_time"].strftime("%H")
    hour = int(hour)
    minute = data3.iloc[i].loc["upload_time"].strftime("%M")
    minute = int(minute)
    hour = hour + ((int)(minute/12))/5.0
    hours.append(hour)
data3["hours"] = hours

# %%
data3
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 1         2908             string         40.0     3544
# 2         2908             string         40.0     3544
# 3         2908             string         40.0     3544
# 4         2908             string         40.0     3544
# ...        ...                ...          ...      ...
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87732     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                   upload_time  score  over_point  days  hours
# 0     2020-02-18 10:54:50.656   40.0    0.000000     2   10.8
# 1     2020-02-24 15:23:50.339    0.0    0.000000     8   15.2
# 2     2020-02-24 15:23:56.610    0.0    0.000000     8   15.2
# 3     2020-02-24 15:28:50.645    0.0    0.000000     8   15.4
# 4     2020-02-24 15:28:59.684    0.0    0.000000     8   15.4
# ...                       ...    ...         ...   ...    ...
# 87729 2020-02-18 01:51:29.121  100.0   83.333333     2    1.8
# 87730 2020-02-23 14:21:57.077  100.0   83.333333     7   14.2
# 87731 2020-02-18 02:02:58.741  100.0   83.333333     2    2.0
# 87732 2020-02-23 14:16:58.780  100.0   83.333333     7   14.2
# 87733 2020-02-17 14:29:28.102    0.0    0.000000     1   14.4
#
# [87734 rows x 9 columns]

# %%
hour_count = data3["hours"].value_counts()
hour_count
# Out:
# 13.2    1750
# 13.4    1664
# 14.4    1545
# 13.8    1516
# 13.6    1500
#         ...
# 22.0       5
# 21.2       5
# 22.6       4
# 21.6       4
# 22.4       3
# Name: hours, Length: 120, dtype: int64

# %%
data4 = data3.drop_duplicates(subset=["case_id","user_id"])
data4
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 24        2172       linear_table        100.0     3544
# 32        2176              array         50.0     3544
# 36        2307              array         25.0     3544
# 37        2804              array          0.0     3544
# ...        ...                ...          ...      ...
# 87728     2534  sorting_algorithm        100.0    47879
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                   upload_time  score  over_point  days  hours
# 0     2020-02-18 10:54:50.656   40.0    0.000000     2   10.8
# 24    2020-03-03 05:31:40.962  100.0  100.000000    16    5.4
# 32    2020-02-17 14:09:14.050    0.0   41.967188     1   14.0
# 36    2020-03-14 14:45:29.500   25.0   41.967188    27   14.6
# 37    2020-02-19 09:09:16.125    0.0   41.967188     3    9.0
# ...                       ...    ...         ...   ...    ...
# 87728 2020-02-18 03:27:02.535  100.0   83.333333     2    3.4
# 87729 2020-02-18 01:51:29.121  100.0   83.333333     2    1.8
# 87730 2020-02-23 14:21:57.077  100.0   83.333333     7   14.2
# 87731 2020-02-18 02:02:58.741  100.0   83.333333     2    2.0
# 87733 2020-02-17 14:29:28.102    0.0    0.000000     1   14.4
#
# [42776 rows x 9 columns]

# %%
hour_count2 = data4["hours"].value_counts()
hour_count2
# Out:
# 13.4    858
# 13.2    844
# 14.2    820
# 13.8    813
# 12.6    802
#        ...
# 21.4      5
# 22.0      5
# 22.6      4
# 22.4      3
# 21.6      3
# Name: hours, Length: 120, dtype: int64

# %%
hour_count.sort_index(inplace=True)
hour_count
# Out:
# 0.0      54
# 0.2     106
# 0.4     179
# 0.6     269
# 0.8     323
#        ...
# 23.0     20
# 23.2     34
# 23.4     37
# 23.6     29
# 23.8     49
# Name: hours, Length: 120, dtype: int64

# %%
plt.plot(hour_count)

# %%
hour_count2.sort_index(inplace=True)
hour_count2
# Out:
# 0.0      29
# 0.2      48
# 0.4      84
# 0.6     129
# 0.8     146
#        ...
# 23.0      9
# 23.2     21
# 23.4     26
# 23.6     25
# 23.8     35
# Name: hours, Length: 120, dtype: int64

# %%
plt.plot(hour_count2)
