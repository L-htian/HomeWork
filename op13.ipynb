# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv("over_point_to_case_type.csv",index_col=[0])
data1
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 1         2908             string         40.0     3544
# 2         2908             string         40.0     3544
# 3         2908             string         40.0     3544
# 4         2908             string         40.0     3544
# ...        ...                ...          ...      ...
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87732     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                    upload_time  score  over_point  days  hours  \
# 0      2020-02-18 18:54:50.656   40.0    0.000000     2   18.8
# 1      2020-02-24 23:23:50.339    0.0    0.000000     8   23.2
# 2      2020-02-24 23:23:56.610    0.0    0.000000     8   23.2
# ...

# %%
data1 = data1[data1["days"]>0]
data1
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 1         2908             string         40.0     3544
# 2         2908             string         40.0     3544
# 3         2908             string         40.0     3544
# 4         2908             string         40.0     3544
# ...        ...                ...          ...      ...
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87732     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                    upload_time  score  over_point  days  hours  \
# 0      2020-02-18 18:54:50.656   40.0    0.000000     2   18.8
# 1      2020-02-24 23:23:50.339    0.0    0.000000     8   23.2
# 2      2020-02-24 23:23:56.610    0.0    0.000000     8   23.2
# ...

# %%
string_data = data1[data1["case_type"] == "string"]
string_data
# Out:
#        case_id case_type  final_score  user_id              upload_time  \
# 0         2908    string         40.0     3544  2020-02-18 18:54:50.656
# 1         2908    string         40.0     3544  2020-02-24 23:23:50.339
# 2         2908    string         40.0     3544  2020-02-24 23:23:56.610
# 3         2908    string         40.0     3544  2020-02-24 23:28:50.645
# 4         2908    string         40.0     3544  2020-02-24 23:28:59.684
# ...        ...       ...          ...      ...                      ...
# 87689     2990    string        100.0    60584  2020-03-12 22:57:43.234
# 87690     2989    string        100.0    60584  2020-03-12 22:57:15.262
# 87710     2987    string        100.0    60728  2020-02-17 18:40:31.607
# 87711     2987    string        100.0    60728  2020-02-17 21:54:04.061
# 87712     2987    string        100.0    60728  2020-02-17 21:55:28.756
#
#        score  over_point  days  hours  upload_time_stamp
# ...

# %%
string_data.index = range(len(string_data))

# %%
string_data
# Out:
#       case_id case_type  final_score  user_id              upload_time  score  \
# 0        2908    string         40.0     3544  2020-02-18 18:54:50.656   40.0
# 1        2908    string         40.0     3544  2020-02-24 23:23:50.339    0.0
# 2        2908    string         40.0     3544  2020-02-24 23:23:56.610    0.0
# 3        2908    string         40.0     3544  2020-02-24 23:28:50.645    0.0
# 4        2908    string         40.0     3544  2020-02-24 23:28:59.684    0.0
# ...       ...       ...          ...      ...                      ...    ...
# 9800     2990    string        100.0    60584  2020-03-12 22:57:43.234  100.0
# 9801     2989    string        100.0    60584  2020-03-12 22:57:15.262  100.0
# 9802     2987    string        100.0    60728  2020-02-17 18:40:31.607  100.0
# 9803     2987    string        100.0    60728  2020-02-17 21:54:04.061    0.0
# 9804     2987    string        100.0    60728  2020-02-17 21:55:28.756  100.0
#
# ...

# %%
string_data.to_csv("score_group_by_case_type/string_data.csv")

# %%
array_data = data1[data1["case_type"] == "array"]
array_data.index = range(len(array_data))
array_data.to_csv("score_group_by_case_type/array_data.csv")

# %%
digital_operation_data = data1[data1["case_type"] == "digital_operation"]
digital_operation_data.index = range(len(digital_operation_data))
digital_operation_data.to_csv("score_group_by_case_type/digital_operation_data.csv")
graph_structure_data = data1[data1["case_type"] == "graph_structure"]
graph_structure_data.index = range(len(graph_structure_data))
graph_structure_data.to_csv("score_group_by_case_type/graph_structure_data.csv")
linear_table_data = data1[data1["case_type"] == "linear_table"]
linear_table_data.index = range(len(linear_table_data))
linear_table_data.to_csv("score_group_by_case_type/linear_table_data.csv")
search_algorithm_data = data1[data1["case_type"] == "search_algorithm"]
search_algorithm_data.index = range(len(search_algorithm_data))
search_algorithm_data.to_csv("score_group_by_case_type/search_algorithm_data.csv")
sorting_algorithm_data = data1[data1["case_type"] == "sorting_algorithm"]
sorting_algorithm_data.index = range(len(sorting_algorithm_data))
sorting_algorithm_data.to_csv("score_group_by_case_type/sorting_algorithm_data.csv")
tree_structure_data = data1[data1["case_type"] == "tree_structure"]
tree_structure_data.index = range(len(tree_structure_data))
tree_structure_data.to_csv("score_group_by_case_type/tree_structure_data.csv")

# %%
data2 = pd.read_csv("over_point_to_user.csv",index_col=[0])
data2
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 1         2908             string         40.0     3544
# 2         2908             string         40.0     3544
# 3         2908             string         40.0     3544
# 4         2908             string         40.0     3544
# ...        ...                ...          ...      ...
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87732     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                    upload_time  score  over_point  days  hours  \
# 0      2020-02-18 18:54:50.656   40.0  160.967187     2   18.8
# 1      2020-02-24 23:23:50.339    0.0  160.967187     8   23.2
# 2      2020-02-24 23:23:56.610    0.0  160.967187     8   23.2
# ...

# %%
data2 = data2[data2["days"]>0]
data2
# Out:
#        case_id          case_type  final_score  user_id  \
# 0         2908             string         40.0     3544
# 1         2908             string         40.0     3544
# 2         2908             string         40.0     3544
# 3         2908             string         40.0     3544
# 4         2908             string         40.0     3544
# ...        ...                ...          ...      ...
# 87729     2533  sorting_algorithm        100.0    47879
# 87730     2542  sorting_algorithm        100.0    47879
# 87731     2528  sorting_algorithm        100.0    47879
# 87732     2528  sorting_algorithm        100.0    47879
# 87733     2542  sorting_algorithm          0.0    60822
#
#                    upload_time  score  over_point  days  hours  \
# 0      2020-02-18 18:54:50.656   40.0  160.967187     2   18.8
# 1      2020-02-24 23:23:50.339    0.0  160.967187     8   23.2
# 2      2020-02-24 23:23:56.610    0.0  160.967187     8   23.2
# ...

# %%
string_data = data2[data2["case_type"] == "string"]
string_data.index = range(len(string_data))
string_data.to_csv("score_group_by_user/string_data.csv")
array_data = data2[data2["case_type"] == "array"]
array_data.index = range(len(array_data))
array_data.to_csv("score_group_by_user/array_data.csv")
digital_operation_data = data2[data2["case_type"] == "digital_operation"]
digital_operation_data.index = range(len(digital_operation_data))
digital_operation_data.to_csv("score_group_by_user/digital_operation_data.csv")
graph_structure_data = data2[data2["case_type"] == "graph_structure"]
graph_structure_data.index = range(len(graph_structure_data))
graph_structure_data.to_csv("score_group_by_user/graph_structure_data.csv")
linear_table_data = data2[data2["case_type"] == "linear_table"]
linear_table_data.index = range(len(linear_table_data))
linear_table_data.to_csv("score_group_by_user/linear_table_data.csv")
search_algorithm_data = data2[data2["case_type"] == "search_algorithm"]
search_algorithm_data.index = range(len(search_algorithm_data))
search_algorithm_data.to_csv("score_group_by_user/search_algorithm_data.csv")
sorting_algorithm_data = data2[data2["case_type"] == "sorting_algorithm"]
sorting_algorithm_data.index = range(len(sorting_algorithm_data))
sorting_algorithm_data.to_csv("score_group_by_user/sorting_algorithm_data.csv")
tree_structure_data = data2[data2["case_type"] == "tree_structure"]
tree_structure_data.index = range(len(tree_structure_data))
tree_structure_data.to_csv("score_group_by_user/tree_structure_data.csv")

# %%
data1.to_csv("over_point_to_case_type.csv")

# %%
data2.to_csv("over_point_to_user.csv")

# %%
data1.index = range(len(data1))

# %%
data1.to_csv("over_point_to_case_type.csv")

# %%
data2.index = range(len(data2))
data2.to_csv("over_point_to_user.csv")
